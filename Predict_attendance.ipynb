# %% [markdown]
# <a href="https://colab.research.google.com/github/GanHD/Dotfiles/blob/master/Predict_attendance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("attendance.csv")
# Out:
#       team  team_name  year   total    home    away  week  weekly_attendance
# 0  Arizona  Cardinals  2000  893926  387475  506451     1            77434.0
# 1  Arizona  Cardinals  2000  893926  387475  506451     2            66009.0
# 2  Arizona  Cardinals  2000  893926  387475  506451     3                NaN
# 3  Arizona  Cardinals  2000  893926  387475  506451     4            71801.0
# 4  Arizona  Cardinals  2000  893926  387475  506451     5            66985.0

# %%
columns_to_remove = ['team', 'total','home','away']
df = df.drop(columns=columns_to_remove)
# Out:
#    team_name  year  week  weekly_attendance
# 0  Cardinals  2000     1            77434.0
# 1  Cardinals  2000     2            66009.0
# 2  Cardinals  2000     3                NaN
# 3  Cardinals  2000     4            71801.0
# 4  Cardinals  2000     5            66985.0

# %%
df = df.dropna(subset=['weekly_attendance'])
# Out:
#    team_name  year  week  weekly_attendance
# 0  Cardinals  2000     1            77434.0
# 1  Cardinals  2000     2            66009.0
# 3  Cardinals  2000     4            71801.0
# 4  Cardinals  2000     5            66985.0
# 5  Cardinals  2000     6            44296.0

# %%
label_encoder = LabelEncoder()
df['team_name'] = label_encoder.fit_transform(df['team_name'])
# Out:
#      team_name  year  week  weekly_attendance
# 0            7  2000     1            77434.0
# 1            7  2000     2            66009.0
# 3            7  2000     4            71801.0
# 4            7  2000     5            66985.0
# 5            7  2000     6            44296.0
# ..         ...   ...   ...                ...
# 632          2  2001     4            62335.0
# 633          2  2001     5            64217.0
# 634          2  2001     6            63408.0
# 635          2  2001     7            69343.0
# 637          2  2001     9            57161.0
#
# [600 rows x 4 columns]

# %%
df = df.sample(frac = 1, random_state=1)

# %%
train_df, test_df = train_test_split(df,test_size=0.2)
# Out:
# 8166 2042

# %%
X_train = train_df[['team_name','year','week']]
y_train = train_df['weekly_attendance']

X_test = test_df[['team_name','year','week']]
y_test = test_df['weekly_attendance']

# %%
# Create a Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_train_pred)
print("Mean Squared Error on training data:", mse)
# Out:
# Mean Squared Error on training data: 82385073.59070884

# %%
user_data = {
}

for feature_name in ['team_name','year','week']:
    value = int(input(f"Enter the value for {feature_name}: "))
    user_data[feature_name] = [value]

user_df = pd.DataFrame(user_data)
predictions = model.predict(user_df)
predictions= int(predictions)
# Print the predictions
print("Predicted output:", predictions)
# Out:
# Enter the value for team_name: 0
# Enter the value for year: 2007
# Enter the value for week: 6
# Predicted output: 67078
